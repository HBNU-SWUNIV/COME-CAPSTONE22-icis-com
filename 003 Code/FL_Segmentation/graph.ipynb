# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
loss = {}
miou = {}

# %%
loss['client_1_loss'] = [0.2572, 0.2552, 0.2517, 0.2494, 0.2475, 0.2437, 0.2433, 0.2408, 0.2370, 0.2338, 0.2340, 0.2293, 0.2296, 0.2268, 0.2265]
miou['client_1_mIOU'] = [0.619, 0.611, 0.618, 0.612, 0.626, 0.612, 0.623, 0.638, 0.625, 0.632, 0.635, 0.617, 0.619, 0.632, 0.617]
loss['client_3_loss'] = [0.3643, 0.3626, 0.3553, 0.3491, 0.3444, 0.3384, 0.3362, 0.3282, 0.3259, 0.3205, 0.3131, 0.3105, 0.3076, 0.3044, 0.2977]
miou['client_3_mIOU'] = [0.529, 0.504, 0.549, 0.506, 0.565, 0.518, 0.507, 0.514, 0.518, 0.507, 0.494, 0.550, 0.521, 0.540, 0.560]
loss['client_5_loss'] = [0.5183, 0.4940, 0.4814, 0.4673, 0.4521, 0.4465, 0.4333, 0.4311, 0.4223, 0.4145, 0.4088, 0.4033, 0.4000, 0.3915, 0.3886]
miou['client_5_mIOU'] = [0.238, 0.333, 0.407, 0.388, 0.377, 0.393, 0.412, 0.404, 0.450, 0.396, 0.411, 0.455, 0.423, 0.429, 0.447]
loss['client_10_loss'] = [0.3526, 0.3489, 0.3469, 0.3405, 0.3387, 0.3378, 0.3367, 0.3314, 0.3301, 0.3297, 0.3278, 0.3277, 0.3238, 0.3207, 0.3196]
miou['client_10_mIOU'] = [0.520, 0.468, 0.515, 0.528, 0.514, 0.533, 0.552, 0.524, 0.538, 0.532, 0.537, 0.522, 0.558, 0.534, 0.521]

# %%
df_loss = pd.DataFrame(loss)
df_miou = pd.DataFrame(miou)

# %%
col = list(df_loss.columns)

plt.figure(figsize=(16,10))
plt.plot(df_loss, 's--', label=col)
plt.ylabel('Epoch')

plt.grid()
plt.legend()
plt.title('LOSS')
plt.show()

# %%
col = list(df_miou.columns)

plt.figure(figsize=(16,10))
plt.plot(df_miou, 's--',label=col)
plt.ylabel('Epoch')
plt.grid()
plt.legend()
plt.title('mIOU')
plt.show()
